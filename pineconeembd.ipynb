# %% [markdown]
# # Task
# Create vector embeddings of the "https://huggingface.co/datasets/openlifescienceai/medmcqa" dataset and upload them to a Pinecone vector database.

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install `git-lfs` and the Pinecone client library.

# %% [markdown]
# **Reasoning**:
# The subtask requires installing two packages, so I will use pip to install them in a single code block.

# %%
# %pip install git-lfs pinecone
# Out:
# Requirement already satisfied: git-lfs in /usr/local/lib/python3.11/dist-packages (1.6)
# Collecting pinecone
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2025.6.15)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone) (4.14.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.4.0)
# Requirement already satisfied: packaging<25.0,>=24.2 in /usr/local/lib/python3.11/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.10)
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 17.6 MB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: pinecone-plugin-assistant, pinecone
# Successfully installed pinecone-7.3.0 pinecone-plugin-assistant-1.7.0

# %% [markdown]
# ## Clone the dataset
#
# ### Subtask:
# Use `git clone` to get the dataset from Hugging Face.

# %% [markdown]
# **Reasoning**:
# Use git clone to download the dataset from the provided Hugging Face URL into a local directory.

# %%
# !git clone https://huggingface.co/datasets/openlifescienceai/medmcqa /tmp/medmcqa
# Out:
# fatal: destination path '/tmp/medmcqa' already exists and is not an empty directory.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the dataset into a pandas DataFrame or similar structure.

# %% [markdown]
# **Reasoning**:
# Import the pandas library and load the dataset from the specified path into a DataFrame. Then, display the head and info of the DataFrame to understand its structure.

# %% [markdown]
# **Reasoning**:
# The previous attempt to load the data failed because the file `train.json` was not found. I need to check the contents of the `/tmp/medmcqa` directory to identify the correct data file(s).

# %%
import os

dataset_path = '/tmp/medmcqa'
print(os.listdir(dataset_path))
# Out:
# ['data', 'README.md', '.git', '.gitattributes']

# %% [markdown]
# **Reasoning**:
# The previous command showed that the data files are likely within the 'data' subdirectory. I will list the contents of the 'data' directory to find the data files.

# %%
import os

data_dir = '/tmp/medmcqa/data'
print(os.listdir(data_dir))
# Out:
# ['validation-00000-of-00001.parquet', 'test-00000-of-00001.parquet', 'train-00000-of-00001.parquet']

# %% [markdown]
# **Reasoning**:
# The previous command revealed that the data files are in Parquet format within the 'data' subdirectory. I will load the 'train-00000-of-00001.parquet' file into a pandas DataFrame and display the head and info.

# %%
import pandas as pd
import os

data_file = '/tmp/medmcqa/data/train-00000-of-00001.parquet'

df = pd.read_parquet(data_file)

display(df.head())
df.info()
# Out:
#                                      id  \
# 0  e9ad821a-c438-4965-9f77-760819dfa155
# 1  e3d3c4e1-4fb2-45e7-9f88-247cc8f373b3
# 2  5c38bea6-787a-44a9-b2df-88f4218ab914
# 3  cdeedb04-fbe9-432c-937c-d53ac24475de
# 4  dc6794a3-b108-47c5-8b1b-3b4931577249
#
#                                             question  \
# 0  Chronic urethral obstruction due to benign pri...
# 1  Which vitamin is supplied from only animal sou...
# 2  All of the following are surgical options for ...
# 3  Following endaerectomy on the right common car...
# 4   Growth hormone has its effect on growth through?
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# 2  Adjustable gastric banding  Biliopancreatic diversion  Duodenal Switch
# 3  Central aery of the retina          Infraorbital aery    Lacrimal aery
# 4                    Directly                      IG1-1        Thyroxine
#
#                           opd  cop choice_type  \
# 0                    Dyplasia    2      single
# 1                   Vitamin D    2      single
# 2  Roux en Y Duodenal By pass    3       multi
# 3          Nasociliary aretry    0       multi
# 4      Intranuclear receptors    1      single
#
#                                                  exp   subject_name  \
# 0  Chronic urethral obstruction because of urinar...        Anatomy
# 1  Ans. (c) Vitamin B12 Ref: Harrison's 19th ed. ...   Biochemistry
# 2  Ans. is 'd' i.e., Roux en Y Duodenal Bypass Ba...        Surgery
# 3  The central aery of the retina is a branch of ...  Ophthalmology
# 4  Ans. is 'b' i.e., IGI-1GH has two major functi...     Physiology
#
#                    topic_name
# 0               Urinary tract
# 1       Vitamins and Minerals
# 2  Surgical Treatment Obesity
# 3                        None
# 4                        None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182822 entries, 0 to 182821
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            182822 non-null  object
#  1   question      182822 non-null  object
#  2   opa           182822 non-null  object
#  3   opb           182822 non-null  object
#  4   opc           182822 non-null  object
#  5   opd           182822 non-null  object
#  6   cop           182822 non-null  int64
#  7   choice_type   182822 non-null  object
#  8   exp           160869 non-null  object
#  9   subject_name  182822 non-null  object
#  10  topic_name    87209 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 15.3+ MB

# %% [markdown]
# ## Process the data
#
# ### Subtask:
# Clean and preprocess the data for embedding. This might involve selecting relevant columns, handling missing values, and formatting text.

# %% [markdown]
# **Reasoning**:
# Select relevant columns, handle missing values, concatenate text, and perform basic text cleaning to prepare the data for embedding.

# %%
# Select relevant columns
selected_cols = ['question', 'opa', 'opb', 'opc', 'opd', 'exp']
df_selected = df[selected_cols].copy()

# Handle missing values: fill with empty strings
df_selected = df_selected.fillna('')

# Concatenate text from selected columns
df_selected['text'] = df_selected['question'] + ' ' + \
                      df_selected['opa'] + ' ' + \
                      df_selected['opb'] + ' ' + \
                      df_selected['opc'] + ' ' + \
                      df_selected['opd'] + ' ' + \
                      df_selected['exp']

# Perform basic text cleaning: convert to lowercase
df_selected['text'] = df_selected['text'].str.lower()

# Display the first few rows of the processed data
display(df_selected[['text']].head())
# Out:
#                                                 text
# 0  chronic urethral obstruction due to benign pri...
# 1  which vitamin is supplied from only animal sou...
# 2  all of the following are surgical options for ...
# 3  following endaerectomy on the right common car...
# 4  growth hormone has its effect on growth throug...

# %% [markdown]
# ## Choose an embedding model
#
# ### Subtask:
# Select a suitable model for creating embeddings (e.g., a sentence transformer or a model from the `transformers` library).

# %% [markdown]
# **Reasoning**:
# Select a suitable pre-trained language model for generating embeddings from the `sentence-transformers` library which is well-suited for generating embeddings for semantic similarity tasks and is commonly used for creating embeddings from text data. The `all-MiniLM-L6-v2` model is a good balance of performance and computational efficiency for general text embeddings.

# %%
from sentence_transformers import SentenceTransformer

model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)

print(f"Selected model: {model_name}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Selected model: all-MiniLM-L6-v2

# %% [markdown]
# ## Generate embeddings
#
# ### Subtask:
# Generate embeddings for the concatenated text data using the chosen sentence transformer model.

# %% [markdown]
# **Reasoning**:
#
# ---
#
#
# Generate embeddings for the 'text' column of the `df_selected` DataFrame using the loaded SentenceTransformer model and store them in a new column.

# %%
import torch

# Check for GPU and set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

embeddings = model.encode(df_selected['text'].tolist(), show_progress_bar=True, device=device)
df_selected['embeddings'] = embeddings.tolist()

display(df_selected[['text', 'embeddings']].head())
# Out:
# Using device: cuda
# Batches:   0%|          | 0/5714 [00:00<?, ?it/s]
#                                                 text  \
# 0  chronic urethral obstruction due to benign pri...
# 1  which vitamin is supplied from only animal sou...
# 2  all of the following are surgical options for ...
# 3  following endaerectomy on the right common car...
# 4  growth hormone has its effect on growth throug...
#
#                                           embeddings
# 0  [0.00010939138155663386, 0.016637397930026054,...
# 1  [-0.030962148681282997, -0.004025406204164028,...
# 2  [0.03295871242880821, -0.006006740033626556, -...
# 3  [0.011834653094410896, 0.0037785270251333714, ...
# 4  [-0.0075697205029428005, -0.025288023054599762...

# %%
display(df_selected[['text', 'embeddings']].head())
# Out:
#                                                 text  \
# 0  chronic urethral obstruction due to benign pri...
# 1  which vitamin is supplied from only animal sou...
# 2  all of the following are surgical options for ...
# 3  following endaerectomy on the right common car...
# 4  growth hormone has its effect on growth throug...
#
#                                           embeddings
# 0  [0.00010939138155663386, 0.016637397930026054,...
# 1  [-0.030962148681282997, -0.004025406204164028,...
# 2  [0.03295871242880821, -0.006006740033626556, -...
# 3  [0.011834653094410896, 0.0037785270251333714, ...
# 4  [-0.0075697205029428005, -0.025288023054599762...

# %%
import os
from pinecone import Pinecone, ServerlessSpec
from google.colab import userdata

PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')

# Initialize Pinecone
pc = Pinecone(api_key=PINECONE_API_KEY)

# Define index name and dimension
index_name = 'medmcqa-embeddings'
embedding_dimension = embeddings.shape[1]

# Create index if it doesn't exist
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=embedding_dimension,
        metric='cosine',
        spec=ServerlessSpec(
            cloud='aws',
            region='us-east-1'
        )
    )

# Connect to the index
pinecone_index = pc.Index(index_name)
print(f"Pinecone index '{index_name}' set up successfully.")

# Prepare data to upload
data_to_upload = []
for idx, row in df_selected.iterrows():
    vector_id = str(df['id'].iloc[idx])
    vector = row['embeddings']
    metadata = {
        'question': df['question'].iloc[idx],
        'opa': df['opa'].iloc[idx],
        'opb': df['opb'].iloc[idx],
        'opc': df['opc'].iloc[idx],
        'opd': df['opd'].iloc[idx],
        'cop': str(df['cop'].iloc[idx]),
        'choice_type': df['choice_type'].iloc[idx],
        'exp': df['exp'].iloc[idx],
        'subject_name': df['subject_name'].iloc[idx],
        'topic_name': df['topic_name'].iloc[idx] if pd.notna(df['topic_name'].iloc[idx]) else ''
    }
    data_to_upload.append((vector_id, vector, metadata))

print(f"Prepared {len(data_to_upload)} data points for upload.")
# Out:
# Pinecone index 'medmcqa-embeddings' set up successfully.
# Prepared 182822 data points for upload.
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-44-1529421637.py in <cell line: 0>()
#      54     batch = data_to_upload[i:i + batch_size]
# ---> 55     pinecone_index.upsert(vectors=batch)
#      56     print(f"Uploaded batch {int(i/batch_size) + 1}/{int(len(data_to_upload)/batch_size)}")
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      29             else:
# ---> 30                 raise e from e
#      31
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      14         try:
# ---> 15             return func(*args, **kwargs)
#      16         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     211         if batch_size is None:
# --> 212             return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     213
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in _upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     237     ) -> UpsertResponse:
# --> 238         return self._vector_api.upsert_vectors(
#     239             IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in __call__(self, *args, **kwargs)
#     101         """
# --> 102         return self.callable(self, *args, **kwargs)
#     103
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py in __upsert_vectors(self, upsert_request, **kwargs)
#     674             kwargs["upsert_request"] = upsert_request
# --> 675             return self.call_with_http_info(**kwargs)
#     676
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in call_with_http_info(self, **kwargs)
#     133
# --> 134         return self.api_client.call_api(
#     135             self.settings["endpoint_path"],
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305         if not async_req:
# --> 306             return self.__call_api(
#     307                 resource_path,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181             e.body = e.body.decode("utf-8")
# --> 182             raise e
#     183
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     169             # perform request and return response
# --> 170             response_data = self.request(
#     171                 method,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385         elif method == "POST":
# --> 386             return self.rest_client.POST(
#     387                 url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     145     ):
# --> 146         return self.request(
#     147             "POST",
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_urllib3.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     266
# --> 267         return raise_exceptions_or_return(r)
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in raise_exceptions_or_return(r)
#      48
# ---> 49         raise PineconeApiException(http_resp=r)
#      50
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 28 Jun 2025 14:29:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '131', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '436', 'x-pinecone-request-id': '7265171089736132733', 'x-envoy-upstream-service-time': '63', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'exp'","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-44-1529421637.py in <cell line: 0>()
#      54     batch = data_to_upload[i:i + batch_size]
# ---> 55     pinecone_index.upsert(vectors=batch)
#      56     print(f"Uploaded batch {int(i/batch_size) + 1}/{int(len(data_to_upload)/batch_size)}")
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      29             else:
# ---> 30                 raise e from e
#      31
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      14         try:
# ---> 15             return func(*args, **kwargs)
#      16         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     211         if batch_size is None:
# --> 212             return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     213
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in _upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     237     ) -> UpsertResponse:
# --> 238         return self._vector_api.upsert_vectors(
#     239             IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in __call__(self, *args, **kwargs)
#     101         """
# --> 102         return self.callable(self, *args, **kwargs)
#     103
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py in __upsert_vectors(self, upsert_request, **kwargs)
#     674             kwargs["upsert_request"] = upsert_request
# --> 675             return self.call_with_http_info(**kwargs)
#     676
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in call_with_http_info(self, **kwargs)
#     133
# --> 134         return self.api_client.call_api(
#     135             self.settings["endpoint_path"],
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305         if not async_req:
# --> 306             return self.__call_api(
#     307                 resource_path,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181             e.body = e.body.decode("utf-8")
# --> 182             raise e
#     183
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     169             # perform request and return response
# --> 170             response_data = self.request(
#     171                 method,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385         elif method == "POST":
# --> 386             return self.rest_client.POST(
#     387                 url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     145     ):
# --> 146         return self.request(
#     147             "POST",
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_urllib3.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     266
# --> 267         return raise_exceptions_or_return(r)
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in raise_exceptions_or_return(r)
#      48
# ---> 49         raise PineconeApiException(http_resp=r)
#      50
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 28 Jun 2025 14:29:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '131', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '436', 'x-pinecone-request-id': '7265171089736132733', 'x-envoy-upstream-service-time': '63', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'exp'","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# /tmp/ipython-input-44-1529421637.py in <cell line: 0>()
#      53 for i in range(0, len(data_to_upload), batch_size):
#      54     batch = data_to_upload[i:i + batch_size]
# ---> 55     pinecone_index.upsert(vectors=batch)
#      56     print(f"Uploaded batch {int(i/batch_size) + 1}/{int(len(data_to_upload)/batch_size)}")
#      57
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      28                 ) from e
#      29             else:
# ---> 30                 raise e from e
#      31
#      32     # Override signature
#
# /usr/local/lib/python3.11/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#      13     def inner_func(*args, **kwargs):
#      14         try:
# ---> 15             return func(*args, **kwargs)
#      16         except Exception as e:
#      17             # Lazy import of urllib3 exceptions
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     210
#     211         if batch_size is None:
# --> 212             return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     213
#     214         if not isinstance(batch_size, int) or batch_size <= 0:
#
# /usr/local/lib/python3.11/dist-packages/pinecone/db_data/index.py in _upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     236         **kwargs,
#     237     ) -> UpsertResponse:
# --> 238         return self._vector_api.upsert_vectors(
#     239             IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     240             **self._openapi_kwargs(kwargs),
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in __call__(self, *args, **kwargs)
#     100
#     101         """
# --> 102         return self.callable(self, *args, **kwargs)
#     103
#     104     def call_with_http_info(self, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py in __upsert_vectors(self, upsert_request, **kwargs)
#     673             kwargs = self._process_openapi_kwargs(kwargs)
#     674             kwargs["upsert_request"] = upsert_request
# --> 675             return self.call_with_http_info(**kwargs)
#     676
#     677         self.upsert_vectors = _Endpoint(
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in call_with_http_info(self, **kwargs)
#     132         HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
#     133
# --> 134         return self.api_client.call_api(
#     135             self.settings["endpoint_path"],
#     136             self.settings["http_method"],
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     304
#     305         if not async_req:
# --> 306             return self.__call_api(
#     307                 resource_path,
#     308                 method,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180         except PineconeApiException as e:
#     181             e.body = e.body.decode("utf-8")
# --> 182             raise e
#     183
#     184         self.last_response = response_data
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168         try:
#     169             # perform request and return response
# --> 170             response_data = self.request(
#     171                 method,
#     172                 url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     384             )
#     385         elif method == "POST":
# --> 386             return self.rest_client.POST(
#     387                 url,
#     388                 query_params=query_params,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     144         _request_timeout=None,
#     145     ):
# --> 146         return self.request(
#     147             "POST",
#     148             url,
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_urllib3.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265             logger.debug("response body: %s", r.data)
#     266
# --> 267         return raise_exceptions_or_return(r)
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/rest_utils.py in raise_exceptions_or_return(r)
#      47             raise ServiceException(http_resp=r)
#      48
# ---> 49         raise PineconeApiException(http_resp=r)
#      50
#      51     return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Sat, 28 Jun 2025 14:29:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '131', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '436', 'x-pinecone-request-id': '7265171089736132733', 'x-envoy-upstream-service-time': '63', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'exp'","details":[]}

# %%
batch_size = 100
for i in range(0, len(data_to_upload), batch_size):
    batch = data_to_upload[i:i + batch_size]
    # fix metadata type issue
    safe_batch = []
    for vid, vec, meta in batch:
        # replace any null/None with empty string for metadata fields
        clean_meta = {k: (v if v is not None else "") for k,v in meta.items()}
        safe_batch.append((vid, vec, clean_meta))
    pinecone_index.upsert(vectors=safe_batch)
    print(f"Uploaded batch {int(i/batch_size) + 1}/{int(len(data_to_upload)/batch_size)}")
print("Upload to Pinecone complete.")
# Out:
# Uploaded batch 1/1828
# Uploaded batch 2/1828
# Uploaded batch 3/1828
# Uploaded batch 4/1828
# Uploaded batch 5/1828
# Uploaded batch 6/1828
# Uploaded batch 7/1828
# Uploaded batch 8/1828
# Uploaded batch 9/1828
# Uploaded batch 10/1828
# Uploaded batch 11/1828
# Uploaded batch 12/1828
# Uploaded batch 13/1828
# Uploaded batch 14/1828
# Uploaded batch 15/1828
# Uploaded batch 16/1828
# Uploaded batch 17/1828
# Uploaded batch 18/1828
# Uploaded batch 19/1828
# Uploaded batch 20/1828
# Uploaded batch 21/1828
# Uploaded batch 22/1828
# Uploaded batch 23/1828
# Uploaded batch 24/1828
# Uploaded batch 25/1828
# Uploaded batch 26/1828
# Uploaded batch 27/1828
# Uploaded batch 28/1828
# Uploaded batch 29/1828
# Uploaded batch 30/1828
# Uploaded batch 31/1828
# Uploaded batch 32/1828
# Uploaded batch 33/1828
# Uploaded batch 34/1828
# Uploaded batch 35/1828
# Uploaded batch 36/1828
# Uploaded batch 37/1828
# Uploaded batch 38/1828
# Uploaded batch 39/1828
# Uploaded batch 40/1828
# Uploaded batch 41/1828
# Uploaded batch 42/1828
# Uploaded batch 43/1828
# Uploaded batch 44/1828
# Uploaded batch 45/1828
# Uploaded batch 46/1828
# Uploaded batch 47/1828
# Uploaded batch 48/1828
# Uploaded batch 49/1828
# Uploaded batch 50/1828
# Uploaded batch 51/1828
# Uploaded batch 52/1828
# Uploaded batch 53/1828
# Uploaded batch 54/1828
# Uploaded batch 55/1828
# Uploaded batch 56/1828
# Uploaded batch 57/1828
# Uploaded batch 58/1828
# Uploaded batch 59/1828
# Uploaded batch 60/1828
# Uploaded batch 61/1828
# Uploaded batch 62/1828
# Uploaded batch 63/1828
# Uploaded batch 64/1828
# Uploaded batch 65/1828
# Uploaded batch 66/1828
# Uploaded batch 67/1828
# Uploaded batch 68/1828
# Uploaded batch 69/1828
# Uploaded batch 70/1828
# Uploaded batch 71/1828
# Uploaded batch 72/1828
# Uploaded batch 73/1828
# Uploaded batch 74/1828
# Uploaded batch 75/1828
# Uploaded batch 76/1828
# Uploaded batch 77/1828
# Uploaded batch 78/1828
# Uploaded batch 79/1828
# Uploaded batch 80/1828
# Uploaded batch 81/1828
# Uploaded batch 82/1828
# Uploaded batch 83/1828
# Uploaded batch 84/1828
# Uploaded batch 85/1828
# Uploaded batch 86/1828
# Uploaded batch 87/1828
# Uploaded batch 88/1828
# Uploaded batch 89/1828
# Uploaded batch 90/1828
# Uploaded batch 91/1828
# Uploaded batch 92/1828
# Uploaded batch 93/1828
# Uploaded batch 94/1828
# Uploaded batch 95/1828
# Uploaded batch 96/1828
# Uploaded batch 97/1828
# Uploaded batch 98/1828
# Uploaded batch 99/1828
# Uploaded batch 100/1828
# Uploaded batch 101/1828
# Uploaded batch 102/1828
# Uploaded batch 103/1828
# Uploaded batch 104/1828
# Uploaded batch 105/1828
# Uploaded batch 106/1828
# Uploaded batch 107/1828
# Uploaded batch 108/1828
# Uploaded batch 109/1828
# Uploaded batch 110/1828
# Uploaded batch 111/1828
# Uploaded batch 112/1828
# Uploaded batch 113/1828
# Uploaded batch 114/1828
# Uploaded batch 115/1828
# Uploaded batch 116/1828
# Uploaded batch 117/1828
# Uploaded batch 118/1828
# Uploaded batch 119/1828
# Uploaded batch 120/1828
# Uploaded batch 121/1828
# Uploaded batch 122/1828
# Uploaded batch 123/1828
# Uploaded batch 124/1828
# Uploaded batch 125/1828
# Uploaded batch 126/1828
# Uploaded batch 127/1828
# Uploaded batch 128/1828
# Uploaded batch 129/1828
# Uploaded batch 130/1828
# Uploaded batch 131/1828
# Uploaded batch 132/1828
# Uploaded batch 133/1828
# Uploaded batch 134/1828
# Uploaded batch 135/1828
# Uploaded batch 136/1828
# Uploaded batch 137/1828
# Uploaded batch 138/1828
# Uploaded batch 139/1828
# Uploaded batch 140/1828
# Uploaded batch 141/1828
# Uploaded batch 142/1828
# Uploaded batch 143/1828
# Uploaded batch 144/1828
# Uploaded batch 145/1828
# Uploaded batch 146/1828
# Uploaded batch 147/1828
# Uploaded batch 148/1828
# Uploaded batch 149/1828
# Uploaded batch 150/1828
# Uploaded batch 151/1828
# Uploaded batch 152/1828
# Uploaded batch 153/1828
# Uploaded batch 154/1828
# Uploaded batch 155/1828
# Uploaded batch 156/1828
# Uploaded batch 157/1828
# Uploaded batch 158/1828
# Uploaded batch 159/1828
# Uploaded batch 160/1828
# Uploaded batch 161/1828
# Uploaded batch 162/1828
# Uploaded batch 163/1828
# Uploaded batch 164/1828
# Uploaded batch 165/1828
# Uploaded batch 166/1828
# Uploaded batch 167/1828
# Uploaded batch 168/1828
# Uploaded batch 169/1828
# Uploaded batch 170/1828
# Uploaded batch 171/1828
# Uploaded batch 172/1828
# Uploaded batch 173/1828
# Uploaded batch 174/1828
# Uploaded batch 175/1828
# Uploaded batch 176/1828
# Uploaded batch 177/1828
# Uploaded batch 178/1828
# Uploaded batch 179/1828
# Uploaded batch 180/1828
# Uploaded batch 181/1828
# Uploaded batch 182/1828
# Uploaded batch 183/1828
# Uploaded batch 184/1828
# Uploaded batch 185/1828
# Uploaded batch 186/1828
# Uploaded batch 187/1828
# Uploaded batch 188/1828
# Uploaded batch 189/1828
# Uploaded batch 190/1828
# Uploaded batch 191/1828
# Uploaded batch 192/1828
# Uploaded batch 193/1828
# Uploaded batch 194/1828
# Uploaded batch 195/1828
# Uploaded batch 196/1828
# Uploaded batch 197/1828
# Uploaded batch 198/1828
# Uploaded batch 199/1828
# Uploaded batch 200/1828
# Uploaded batch 201/1828
# Uploaded batch 202/1828
# Uploaded batch 203/1828
# Uploaded batch 204/1828
# Uploaded batch 205/1828
# Uploaded batch 206/1828
# Uploaded batch 207/1828
# Uploaded batch 208/1828
# Uploaded batch 209/1828
# Uploaded batch 210/1828
# Uploaded batch 211/1828
# Uploaded batch 212/1828
# Uploaded batch 213/1828
# Uploaded batch 214/1828
# Uploaded batch 215/1828
# Uploaded batch 216/1828
# Uploaded batch 217/1828
# Uploaded batch 218/1828
# Uploaded batch 219/1828
# Uploaded batch 220/1828
# Uploaded batch 221/1828
# Uploaded batch 222/1828
# Uploaded batch 223/1828
# Uploaded batch 224/1828
# Uploaded batch 225/1828
# Uploaded batch 226/1828
# Uploaded batch 227/1828
# Uploaded batch 228/1828
# Uploaded batch 229/1828
# Uploaded batch 230/1828
# Uploaded batch 231/1828
# Uploaded batch 232/1828
# Uploaded batch 233/1828
# Uploaded batch 234/1828
# Uploaded batch 235/1828
# Uploaded batch 236/1828
# Uploaded batch 237/1828
# Uploaded batch 238/1828
# Uploaded batch 239/1828
# Uploaded batch 240/1828
# Uploaded batch 241/1828
# Uploaded batch 242/1828
# Uploaded batch 243/1828
# Uploaded batch 244/1828
# Uploaded batch 245/1828
# Uploaded batch 246/1828
# Uploaded batch 247/1828
# Uploaded batch 248/1828
# Uploaded batch 249/1828
# Uploaded batch 250/1828
# Uploaded batch 251/1828
# Uploaded batch 252/1828
# Uploaded batch 253/1828
# Uploaded batch 254/1828
# Uploaded batch 255/1828
# Uploaded batch 256/1828
# Uploaded batch 257/1828
# Uploaded batch 258/1828
# Uploaded batch 259/1828
# Uploaded batch 260/1828
# Uploaded batch 261/1828
# Uploaded batch 262/1828
# Uploaded batch 263/1828
# Uploaded batch 264/1828
# Uploaded batch 265/1828
# Uploaded batch 266/1828
# Uploaded batch 267/1828
# Uploaded batch 268/1828
# Uploaded batch 269/1828
# Uploaded batch 270/1828
# Uploaded batch 271/1828
# Uploaded batch 272/1828
# Uploaded batch 273/1828
# Uploaded batch 274/1828
# Uploaded batch 275/1828
# Uploaded batch 276/1828
# Uploaded batch 277/1828
# Uploaded batch 278/1828
# Uploaded batch 279/1828
# Uploaded batch 280/1828
# Uploaded batch 281/1828
# Uploaded batch 282/1828
# Uploaded batch 283/1828
# Uploaded batch 284/1828
# Uploaded batch 285/1828
# Uploaded batch 286/1828
# Uploaded batch 287/1828
# Uploaded batch 288/1828
# Uploaded batch 289/1828
# Uploaded batch 290/1828
# Uploaded batch 291/1828
# Uploaded batch 292/1828
# Uploaded batch 293/1828
# Uploaded batch 294/1828
# Uploaded batch 295/1828
# Uploaded batch 296/1828
# Uploaded batch 297/1828
# Uploaded batch 298/1828
# Uploaded batch 299/1828
# Uploaded batch 300/1828
# Uploaded batch 301/1828
# Uploaded batch 302/1828
# Uploaded batch 303/1828
# Uploaded batch 304/1828
# Uploaded batch 305/1828
# Uploaded batch 306/1828
# Uploaded batch 307/1828
# Uploaded batch 308/1828
# Uploaded batch 309/1828
# Uploaded batch 310/1828
# Uploaded batch 311/1828
# Uploaded batch 312/1828
# Uploaded batch 313/1828
# Uploaded batch 314/1828
# Uploaded batch 315/1828
# Uploaded batch 316/1828
# Uploaded batch 317/1828
# Uploaded batch 318/1828
# Uploaded batch 319/1828
# Uploaded batch 320/1828
# Uploaded batch 321/1828
# Uploaded batch 322/1828
# Uploaded batch 323/1828
# Uploaded batch 324/1828
# Uploaded batch 325/1828
# Uploaded batch 326/1828
# Uploaded batch 327/1828
# Uploaded batch 328/1828
# Uploaded batch 329/1828
# Uploaded batch 330/1828
# Uploaded batch 331/1828
# Uploaded batch 332/1828
# Uploaded batch 333/1828
# Uploaded batch 334/1828
# Uploaded batch 335/1828
# Uploaded batch 336/1828
# Uploaded batch 337/1828
# Uploaded batch 338/1828
# Uploaded batch 339/1828
# Uploaded batch 340/1828
# Uploaded batch 341/1828
# Uploaded batch 342/1828
# Uploaded batch 343/1828
# Uploaded batch 344/1828
# Uploaded batch 345/1828
# Uploaded batch 346/1828
# Uploaded batch 347/1828
# Uploaded batch 348/1828
# Uploaded batch 349/1828
# Uploaded batch 350/1828
# Uploaded batch 351/1828
# Uploaded batch 352/1828
# Uploaded batch 353/1828
# Uploaded batch 354/1828
# Uploaded batch 355/1828
# Uploaded batch 356/1828
# Uploaded batch 357/1828
# Uploaded batch 358/1828
# Uploaded batch 359/1828
# Uploaded batch 360/1828
# Uploaded batch 361/1828
# Uploaded batch 362/1828
# Uploaded batch 363/1828
# Uploaded batch 364/1828
# Uploaded batch 365/1828
# Uploaded batch 366/1828
# Uploaded batch 367/1828
# Uploaded batch 368/1828
# Uploaded batch 369/1828
# Uploaded batch 370/1828
# Uploaded batch 371/1828
# Uploaded batch 372/1828
# Uploaded batch 373/1828
# Uploaded batch 374/1828
# Uploaded batch 375/1828
# Uploaded batch 376/1828
# Uploaded batch 377/1828
# Uploaded batch 378/1828
# Uploaded batch 379/1828
# Uploaded batch 380/1828
# Uploaded batch 381/1828
# Uploaded batch 382/1828
# Uploaded batch 383/1828
# Uploaded batch 384/1828
# Uploaded batch 385/1828
# Uploaded batch 386/1828
# Uploaded batch 387/1828
# Uploaded batch 388/1828
# Uploaded batch 389/1828
# Uploaded batch 390/1828
# Uploaded batch 391/1828
# Uploaded batch 392/1828
# Uploaded batch 393/1828
# Uploaded batch 394/1828
# Uploaded batch 395/1828
# Uploaded batch 396/1828
# Uploaded batch 397/1828
# Uploaded batch 398/1828
# Uploaded batch 399/1828
# Uploaded batch 400/1828
# Uploaded batch 401/1828
# Uploaded batch 402/1828
# Uploaded batch 403/1828
# Uploaded batch 404/1828
# Uploaded batch 405/1828
# Uploaded batch 406/1828
# Uploaded batch 407/1828
# Uploaded batch 408/1828
# Uploaded batch 409/1828
# Uploaded batch 410/1828
# Uploaded batch 411/1828
# Uploaded batch 412/1828
# Uploaded batch 413/1828
# Uploaded batch 414/1828
# Uploaded batch 415/1828
# Uploaded batch 416/1828
# Uploaded batch 417/1828
# Uploaded batch 418/1828
# Uploaded batch 419/1828
# Uploaded batch 420/1828
# Uploaded batch 421/1828
# Uploaded batch 422/1828
# Uploaded batch 423/1828
# Uploaded batch 424/1828
# Uploaded batch 425/1828
# Uploaded batch 426/1828
# Uploaded batch 427/1828
# Uploaded batch 428/1828
# Uploaded batch 429/1828
# Uploaded batch 430/1828
# Uploaded batch 431/1828
# Uploaded batch 432/1828
# Uploaded batch 433/1828
# Uploaded batch 434/1828
# Uploaded batch 435/1828
# Uploaded batch 436/1828
# Uploaded batch 437/1828
# Uploaded batch 438/1828
# Uploaded batch 439/1828
# Uploaded batch 440/1828
# Uploaded batch 441/1828
# Uploaded batch 442/1828
# Uploaded batch 443/1828
# Uploaded batch 444/1828
# Uploaded batch 445/1828
# Uploaded batch 446/1828
# Uploaded batch 447/1828
# Uploaded batch 448/1828
# Uploaded batch 449/1828
# Uploaded batch 450/1828
# Uploaded batch 451/1828
# Uploaded batch 452/1828
# Uploaded batch 453/1828
# Uploaded batch 454/1828
# Uploaded batch 455/1828
# Uploaded batch 456/1828
# Uploaded batch 457/1828
# Uploaded batch 458/1828
# Uploaded batch 459/1828
# Uploaded batch 460/1828
# Uploaded batch 461/1828
# Uploaded batch 462/1828
# Uploaded batch 463/1828
# Uploaded batch 464/1828
# Uploaded batch 465/1828
# Uploaded batch 466/1828
# Uploaded batch 467/1828
# Uploaded batch 468/1828
# Uploaded batch 469/1828
# Uploaded batch 470/1828
# Uploaded batch 471/1828
# Uploaded batch 472/1828
# Uploaded batch 473/1828
# Uploaded batch 474/1828
# Uploaded batch 475/1828
# Uploaded batch 476/1828
# Uploaded batch 477/1828
# Uploaded batch 478/1828
# Uploaded batch 479/1828
# Uploaded batch 480/1828
# Uploaded batch 481/1828
# Uploaded batch 482/1828
# Uploaded batch 483/1828
# Uploaded batch 484/1828
# Uploaded batch 485/1828
# Uploaded batch 486/1828
# Uploaded batch 487/1828
# Uploaded batch 488/1828
# Uploaded batch 489/1828
# Uploaded batch 490/1828
# Uploaded batch 491/1828
# Uploaded batch 492/1828
# Uploaded batch 493/1828
# Uploaded batch 494/1828
# Uploaded batch 495/1828
# Uploaded batch 496/1828
# Uploaded batch 497/1828
# Uploaded batch 498/1828
# Uploaded batch 499/1828
# Uploaded batch 500/1828
# Uploaded batch 501/1828
# Uploaded batch 502/1828
# Uploaded batch 503/1828
# Uploaded batch 504/1828
# Uploaded batch 505/1828
# Uploaded batch 506/1828
# Uploaded batch 507/1828
# Uploaded batch 508/1828
# Uploaded batch 509/1828
# Uploaded batch 510/1828
# Uploaded batch 511/1828
# Uploaded batch 512/1828
# Uploaded batch 513/1828
# Uploaded batch 514/1828
# Uploaded batch 515/1828
# Uploaded batch 516/1828
# Uploaded batch 517/1828
# Uploaded batch 518/1828
# Uploaded batch 519/1828
# Uploaded batch 520/1828
# Uploaded batch 521/1828
# Uploaded batch 522/1828
# Uploaded batch 523/1828
# Uploaded batch 524/1828
# Uploaded batch 525/1828
# Uploaded batch 526/1828
# Uploaded batch 527/1828
# Uploaded batch 528/1828
# Uploaded batch 529/1828
# Uploaded batch 530/1828
# Uploaded batch 531/1828
# Uploaded batch 532/1828
# Uploaded batch 533/1828
# Uploaded batch 534/1828
# Uploaded batch 535/1828
# Uploaded batch 536/1828
# Uploaded batch 537/1828
# Uploaded batch 538/1828
# Uploaded batch 539/1828
# Uploaded batch 540/1828
# Uploaded batch 541/1828
# Uploaded batch 542/1828
# Uploaded batch 543/1828
# Uploaded batch 544/1828
# Uploaded batch 545/1828
# Uploaded batch 546/1828
# Uploaded batch 547/1828
# Uploaded batch 548/1828
# Uploaded batch 549/1828
# Uploaded batch 550/1828
# Uploaded batch 551/1828
# Uploaded batch 552/1828
# Uploaded batch 553/1828
# Uploaded batch 554/1828
# Uploaded batch 555/1828
# Uploaded batch 556/1828
# Uploaded batch 557/1828
# Uploaded batch 558/1828
# Uploaded batch 559/1828
# Uploaded batch 560/1828
# Uploaded batch 561/1828
# Uploaded batch 562/1828
# Uploaded batch 563/1828
# Uploaded batch 564/1828
# Uploaded batch 565/1828
# Uploaded batch 566/1828
# Uploaded batch 567/1828
# Uploaded batch 568/1828
# Uploaded batch 569/1828
# Uploaded batch 570/1828
# Uploaded batch 571/1828
# Uploaded batch 572/1828
# Uploaded batch 573/1828
# Uploaded batch 574/1828
# Uploaded batch 575/1828
# Uploaded batch 576/1828
# Uploaded batch 577/1828
# Uploaded batch 578/1828
# Uploaded batch 579/1828
# Uploaded batch 580/1828
# Uploaded batch 581/1828
# Uploaded batch 582/1828
# Uploaded batch 583/1828
# Uploaded batch 584/1828
# Uploaded batch 585/1828
# Uploaded batch 586/1828
# Uploaded batch 587/1828
# Uploaded batch 588/1828
# Uploaded batch 589/1828
# Uploaded batch 590/1828
# Uploaded batch 591/1828
# Uploaded batch 592/1828
# Uploaded batch 593/1828
# Uploaded batch 594/1828
# Uploaded batch 595/1828
# Uploaded batch 596/1828
# Uploaded batch 597/1828
# Uploaded batch 598/1828
# Uploaded batch 599/1828
# Uploaded batch 600/1828
# Uploaded batch 601/1828
# Uploaded batch 602/1828
# Uploaded batch 603/1828
# Uploaded batch 604/1828
# Uploaded batch 605/1828
# Uploaded batch 606/1828
# Uploaded batch 607/1828
# Uploaded batch 608/1828
# Uploaded batch 609/1828
# Uploaded batch 610/1828
# Uploaded batch 611/1828
# Uploaded batch 612/1828
# Uploaded batch 613/1828
# Uploaded batch 614/1828
# Uploaded batch 615/1828
# Uploaded batch 616/1828
# Uploaded batch 617/1828
# Uploaded batch 618/1828
# Uploaded batch 619/1828
# Uploaded batch 620/1828
# Uploaded batch 621/1828
# Uploaded batch 622/1828
# Uploaded batch 623/1828
# Uploaded batch 624/1828
# Uploaded batch 625/1828
# Uploaded batch 626/1828
# Uploaded batch 627/1828
# Uploaded batch 628/1828
# Uploaded batch 629/1828
# Uploaded batch 630/1828
# Uploaded batch 631/1828
# Uploaded batch 632/1828
# Uploaded batch 633/1828
# Uploaded batch 634/1828
# Uploaded batch 635/1828
# Uploaded batch 636/1828
# Uploaded batch 637/1828
# Uploaded batch 638/1828
# Uploaded batch 639/1828
# Uploaded batch 640/1828
# Uploaded batch 641/1828
# Uploaded batch 642/1828
# Uploaded batch 643/1828
# Uploaded batch 644/1828
# Uploaded batch 645/1828
# Uploaded batch 646/1828
# Uploaded batch 647/1828
# Uploaded batch 648/1828
# Uploaded batch 649/1828
# Uploaded batch 650/1828
# Uploaded batch 651/1828
# Uploaded batch 652/1828
# Uploaded batch 653/1828
# Uploaded batch 654/1828
# Uploaded batch 655/1828
# Uploaded batch 656/1828
# Uploaded batch 657/1828
# Uploaded batch 658/1828
# Uploaded batch 659/1828
# Uploaded batch 660/1828
# Uploaded batch 661/1828
# Uploaded batch 662/1828
# Uploaded batch 663/1828
# Uploaded batch 664/1828
# Uploaded batch 665/1828
# Uploaded batch 666/1828
# Uploaded batch 667/1828
# Uploaded batch 668/1828
# Uploaded batch 669/1828
# Uploaded batch 670/1828
# Uploaded batch 671/1828
# Uploaded batch 672/1828
# Uploaded batch 673/1828
# Uploaded batch 674/1828
# Uploaded batch 675/1828
# Uploaded batch 676/1828
# Uploaded batch 677/1828
# Uploaded batch 678/1828
# Uploaded batch 679/1828
# Uploaded batch 680/1828
# Uploaded batch 681/1828
# Uploaded batch 682/1828
# Uploaded batch 683/1828
# Uploaded batch 684/1828
# Uploaded batch 685/1828
# Uploaded batch 686/1828
# Uploaded batch 687/1828
# Uploaded batch 688/1828
# Uploaded batch 689/1828
# Uploaded batch 690/1828
# Uploaded batch 691/1828
# Uploaded batch 692/1828
# Uploaded batch 693/1828
# Uploaded batch 694/1828
# Uploaded batch 695/1828
# Uploaded batch 696/1828
# Uploaded batch 697/1828
# Uploaded batch 698/1828
# Uploaded batch 699/1828
# Uploaded batch 700/1828
# Uploaded batch 701/1828
# Uploaded batch 702/1828
# Uploaded batch 703/1828
# Uploaded batch 704/1828
# Uploaded batch 705/1828
# Uploaded batch 706/1828
# Uploaded batch 707/1828
# Uploaded batch 708/1828
# Uploaded batch 709/1828
# Uploaded batch 710/1828
# Uploaded batch 711/1828
# Uploaded batch 712/1828
# Uploaded batch 713/1828
# Uploaded batch 714/1828
# Uploaded batch 715/1828
# Uploaded batch 716/1828
# Uploaded batch 717/1828
# Uploaded batch 718/1828
# Uploaded batch 719/1828
# Uploaded batch 720/1828
# Uploaded batch 721/1828
# Uploaded batch 722/1828
# Uploaded batch 723/1828
# Uploaded batch 724/1828
# Uploaded batch 725/1828
# Uploaded batch 726/1828
# Uploaded batch 727/1828
# Uploaded batch 728/1828
# Uploaded batch 729/1828
# Uploaded batch 730/1828
# Uploaded batch 731/1828
# Uploaded batch 732/1828
# Uploaded batch 733/1828
# Uploaded batch 734/1828
# Uploaded batch 735/1828
# Uploaded batch 736/1828
# Uploaded batch 737/1828
# Uploaded batch 738/1828
# Uploaded batch 739/1828
# Uploaded batch 740/1828
# Uploaded batch 741/1828
# Uploaded batch 742/1828
# Uploaded batch 743/1828
# Uploaded batch 744/1828
# Uploaded batch 745/1828
# Uploaded batch 746/1828
# Uploaded batch 747/1828
# Uploaded batch 748/1828
# Uploaded batch 749/1828
# Uploaded batch 750/1828
# Uploaded batch 751/1828
# Uploaded batch 752/1828
# Uploaded batch 753/1828
# Uploaded batch 754/1828
# Uploaded batch 755/1828
# Uploaded batch 756/1828
# Uploaded batch 757/1828
# Uploaded batch 758/1828
# Uploaded batch 759/1828
# Uploaded batch 760/1828
# Uploaded batch 761/1828
# Uploaded batch 762/1828
# Uploaded batch 763/1828
# Uploaded batch 764/1828
# Uploaded batch 765/1828
# Uploaded batch 766/1828
# Uploaded batch 767/1828
# Uploaded batch 768/1828
# Uploaded batch 769/1828
# Uploaded batch 770/1828
# Uploaded batch 771/1828
# Uploaded batch 772/1828
# Uploaded batch 773/1828
# Uploaded batch 774/1828
# Uploaded batch 775/1828
# Uploaded batch 776/1828
# Uploaded batch 777/1828
# Uploaded batch 778/1828
# Uploaded batch 779/1828
# Uploaded batch 780/1828
# Uploaded batch 781/1828
# Uploaded batch 782/1828
# Uploaded batch 783/1828
# Uploaded batch 784/1828
# Uploaded batch 785/1828
# Uploaded batch 786/1828
# Uploaded batch 787/1828
# Uploaded batch 788/1828
# Uploaded batch 789/1828
# Uploaded batch 790/1828
# Uploaded batch 791/1828
# Uploaded batch 792/1828
# Uploaded batch 793/1828
# Uploaded batch 794/1828
# Uploaded batch 795/1828
# Uploaded batch 796/1828
# Uploaded batch 797/1828
# Uploaded batch 798/1828
# Uploaded batch 799/1828
# Uploaded batch 800/1828
# Uploaded batch 801/1828
# Uploaded batch 802/1828
# Uploaded batch 803/1828
# Uploaded batch 804/1828
# Uploaded batch 805/1828
# Uploaded batch 806/1828
# Uploaded batch 807/1828
# Uploaded batch 808/1828
# Uploaded batch 809/1828
# Uploaded batch 810/1828
# Uploaded batch 811/1828
# Uploaded batch 812/1828
# Uploaded batch 813/1828
# Uploaded batch 814/1828
# Uploaded batch 815/1828
# Uploaded batch 816/1828
# Uploaded batch 817/1828
# Uploaded batch 818/1828
# Uploaded batch 819/1828
# Uploaded batch 820/1828
# Uploaded batch 821/1828
# Uploaded batch 822/1828
# Uploaded batch 823/1828
# Uploaded batch 824/1828
# Uploaded batch 825/1828
# Uploaded batch 826/1828
# Uploaded batch 827/1828
# Uploaded batch 828/1828
# Uploaded batch 829/1828
# Uploaded batch 830/1828
# Uploaded batch 831/1828
# Uploaded batch 832/1828
# Uploaded batch 833/1828
# Uploaded batch 834/1828
# Uploaded batch 835/1828
# Uploaded batch 836/1828
# Uploaded batch 837/1828
# Uploaded batch 838/1828
# Uploaded batch 839/1828
# Uploaded batch 840/1828
# Uploaded batch 841/1828
# Uploaded batch 842/1828
# Uploaded batch 843/1828
# Uploaded batch 844/1828
# Uploaded batch 845/1828
# Uploaded batch 846/1828
# Uploaded batch 847/1828
# Uploaded batch 848/1828
# Uploaded batch 849/1828
# Uploaded batch 850/1828
# Uploaded batch 851/1828
# Uploaded batch 852/1828
# Uploaded batch 853/1828
# Uploaded batch 854/1828
# Uploaded batch 855/1828
# Uploaded batch 856/1828
# Uploaded batch 857/1828
# Uploaded batch 858/1828
# Uploaded batch 859/1828
# Uploaded batch 860/1828
# Uploaded batch 861/1828
# Uploaded batch 862/1828
# Uploaded batch 863/1828
# Uploaded batch 864/1828
# Uploaded batch 865/1828
# Uploaded batch 866/1828
# Uploaded batch 867/1828
# Uploaded batch 868/1828
# Uploaded batch 869/1828
# Uploaded batch 870/1828
# Uploaded batch 871/1828
# Uploaded batch 872/1828
# Uploaded batch 873/1828
# Uploaded batch 874/1828
# Uploaded batch 875/1828
# Uploaded batch 876/1828
# Uploaded batch 877/1828
# Uploaded batch 878/1828
# Uploaded batch 879/1828
# Uploaded batch 880/1828
# Uploaded batch 881/1828
# Uploaded batch 882/1828
# Uploaded batch 883/1828
# Uploaded batch 884/1828
# Uploaded batch 885/1828
# Uploaded batch 886/1828
# Uploaded batch 887/1828
# Uploaded batch 888/1828
# Uploaded batch 889/1828
# Uploaded batch 890/1828
# Uploaded batch 891/1828
# Uploaded batch 892/1828
# Uploaded batch 893/1828
# Uploaded batch 894/1828
# Uploaded batch 895/1828
# Uploaded batch 896/1828
# Uploaded batch 897/1828
# Uploaded batch 898/1828
# Uploaded batch 899/1828
# Uploaded batch 900/1828
# Uploaded batch 901/1828
# Uploaded batch 902/1828
# Uploaded batch 903/1828
# Uploaded batch 904/1828
# Uploaded batch 905/1828
# Uploaded batch 906/1828
# Uploaded batch 907/1828
# Uploaded batch 908/1828
# Uploaded batch 909/1828
# Uploaded batch 910/1828
# Uploaded batch 911/1828
# Uploaded batch 912/1828
# Uploaded batch 913/1828
# Uploaded batch 914/1828
# Uploaded batch 915/1828
# Uploaded batch 916/1828
# Uploaded batch 917/1828
# Uploaded batch 918/1828
# Uploaded batch 919/1828
# Uploaded batch 920/1828
# Uploaded batch 921/1828
# Uploaded batch 922/1828
# Uploaded batch 923/1828
# Uploaded batch 924/1828
# Uploaded batch 925/1828
# Uploaded batch 926/1828
# Uploaded batch 927/1828
# Uploaded batch 928/1828
# Uploaded batch 929/1828
# Uploaded batch 930/1828
# Uploaded batch 931/1828
# Uploaded batch 932/1828
# Uploaded batch 933/1828
# Uploaded batch 934/1828
# Uploaded batch 935/1828
# Uploaded batch 936/1828
# Uploaded batch 937/1828
# Uploaded batch 938/1828
# Uploaded batch 939/1828
# Uploaded batch 940/1828
# Uploaded batch 941/1828
# Uploaded batch 942/1828
# Uploaded batch 943/1828
# Uploaded batch 944/1828
# Uploaded batch 945/1828
# Uploaded batch 946/1828
# Uploaded batch 947/1828
# Uploaded batch 948/1828
# Uploaded batch 949/1828
# Uploaded batch 950/1828
# Uploaded batch 951/1828
# Uploaded batch 952/1828
# Uploaded batch 953/1828
# Uploaded batch 954/1828
# Uploaded batch 955/1828
# Uploaded batch 956/1828
# Uploaded batch 957/1828
# Uploaded batch 958/1828
# Uploaded batch 959/1828
# Uploaded batch 960/1828
# Uploaded batch 961/1828
# Uploaded batch 962/1828
# Uploaded batch 963/1828
# Uploaded batch 964/1828
# Uploaded batch 965/1828
# Uploaded batch 966/1828
# Uploaded batch 967/1828
# Uploaded batch 968/1828
# Uploaded batch 969/1828
# Uploaded batch 970/1828
# Uploaded batch 971/1828
# Uploaded batch 972/1828
# Uploaded batch 973/1828
# Uploaded batch 974/1828
# Uploaded batch 975/1828
# Uploaded batch 976/1828
# Uploaded batch 977/1828
# Uploaded batch 978/1828
# Uploaded batch 979/1828
# Uploaded batch 980/1828
# Uploaded batch 981/1828
# Uploaded batch 982/1828
# Uploaded batch 983/1828
# Uploaded batch 984/1828
# Uploaded batch 985/1828
# Uploaded batch 986/1828
# Uploaded batch 987/1828
# Uploaded batch 988/1828
# Uploaded batch 989/1828
# Uploaded batch 990/1828
# Uploaded batch 991/1828
# Uploaded batch 992/1828
# Uploaded batch 993/1828
# Uploaded batch 994/1828
# Uploaded batch 995/1828
# Uploaded batch 996/1828
# Uploaded batch 997/1828
# Uploaded batch 998/1828
# Uploaded batch 999/1828
# Uploaded batch 1000/1828
# Uploaded batch 1001/1828
# Uploaded batch 1002/1828
# Uploaded batch 1003/1828
# Uploaded batch 1004/1828
# Uploaded batch 1005/1828
# Uploaded batch 1006/1828
# Uploaded batch 1007/1828
# Uploaded batch 1008/1828
# Uploaded batch 1009/1828
# Uploaded batch 1010/1828
# Uploaded batch 1011/1828
# Uploaded batch 1012/1828
# Uploaded batch 1013/1828
# Uploaded batch 1014/1828
# Uploaded batch 1015/1828
# Uploaded batch 1016/1828
# Uploaded batch 1017/1828
# Uploaded batch 1018/1828
# Uploaded batch 1019/1828
# Uploaded batch 1020/1828
# Uploaded batch 1021/1828
# Uploaded batch 1022/1828
# Uploaded batch 1023/1828
# Uploaded batch 1024/1828
# Uploaded batch 1025/1828
# Uploaded batch 1026/1828
# Uploaded batch 1027/1828
# Uploaded batch 1028/1828
# Uploaded batch 1029/1828
# Uploaded batch 1030/1828
# Uploaded batch 1031/1828
# Uploaded batch 1032/1828
# Uploaded batch 1033/1828
# Uploaded batch 1034/1828
# Uploaded batch 1035/1828
# Uploaded batch 1036/1828
# Uploaded batch 1037/1828
# Uploaded batch 1038/1828
# Uploaded batch 1039/1828
# Uploaded batch 1040/1828
# Uploaded batch 1041/1828
# Uploaded batch 1042/1828
# Uploaded batch 1043/1828
# Uploaded batch 1044/1828
# Uploaded batch 1045/1828
# Uploaded batch 1046/1828
# Uploaded batch 1047/1828
# Uploaded batch 1048/1828
# Uploaded batch 1049/1828
# Uploaded batch 1050/1828
# Uploaded batch 1051/1828
# Uploaded batch 1052/1828
# Uploaded batch 1053/1828
# Uploaded batch 1054/1828
# Uploaded batch 1055/1828
# Uploaded batch 1056/1828
# Uploaded batch 1057/1828
# Uploaded batch 1058/1828
# Uploaded batch 1059/1828
# Uploaded batch 1060/1828
# Uploaded batch 1061/1828
# Uploaded batch 1062/1828
# Uploaded batch 1063/1828
# Uploaded batch 1064/1828
# Uploaded batch 1065/1828
# Uploaded batch 1066/1828
# Uploaded batch 1067/1828
# Uploaded batch 1068/1828
# Uploaded batch 1069/1828
# Uploaded batch 1070/1828
# Uploaded batch 1071/1828
# Uploaded batch 1072/1828
# Uploaded batch 1073/1828
# Uploaded batch 1074/1828
# Uploaded batch 1075/1828
# Uploaded batch 1076/1828
# Uploaded batch 1077/1828
# Uploaded batch 1078/1828
# Uploaded batch 1079/1828
# Uploaded batch 1080/1828
# Uploaded batch 1081/1828
# Uploaded batch 1082/1828
# Uploaded batch 1083/1828
# Uploaded batch 1084/1828
# Uploaded batch 1085/1828
# Uploaded batch 1086/1828
# Uploaded batch 1087/1828
# Uploaded batch 1088/1828
# Uploaded batch 1089/1828
# Uploaded batch 1090/1828
# Uploaded batch 1091/1828
# Uploaded batch 1092/1828
# Uploaded batch 1093/1828
# Uploaded batch 1094/1828
# Uploaded batch 1095/1828
# Uploaded batch 1096/1828
# Uploaded batch 1097/1828
# Uploaded batch 1098/1828
# Uploaded batch 1099/1828
# Uploaded batch 1100/1828
# Uploaded batch 1101/1828
# Uploaded batch 1102/1828
# Uploaded batch 1103/1828
# Uploaded batch 1104/1828
# Uploaded batch 1105/1828
# Uploaded batch 1106/1828
# Uploaded batch 1107/1828
# Uploaded batch 1108/1828
# Uploaded batch 1109/1828
# Uploaded batch 1110/1828
# Uploaded batch 1111/1828
# Uploaded batch 1112/1828
# Uploaded batch 1113/1828
# Uploaded batch 1114/1828
# Uploaded batch 1115/1828
# Uploaded batch 1116/1828
# Uploaded batch 1117/1828
# Uploaded batch 1118/1828
# Uploaded batch 1119/1828
# Uploaded batch 1120/1828
# Uploaded batch 1121/1828
# Uploaded batch 1122/1828
# Uploaded batch 1123/1828
# Uploaded batch 1124/1828
# Uploaded batch 1125/1828
# Uploaded batch 1126/1828
# Uploaded batch 1127/1828
# Uploaded batch 1128/1828
# Uploaded batch 1129/1828
# Uploaded batch 1130/1828
# Uploaded batch 1131/1828
# Uploaded batch 1132/1828
# Uploaded batch 1133/1828
# Uploaded batch 1134/1828
# Uploaded batch 1135/1828
# Uploaded batch 1136/1828
# Uploaded batch 1137/1828
# Uploaded batch 1138/1828
# Uploaded batch 1139/1828
# Uploaded batch 1140/1828
# Uploaded batch 1141/1828
# Uploaded batch 1142/1828
# Uploaded batch 1143/1828
# Uploaded batch 1144/1828
# Uploaded batch 1145/1828
# Uploaded batch 1146/1828
# Uploaded batch 1147/1828
# Uploaded batch 1148/1828
# Uploaded batch 1149/1828
# Uploaded batch 1150/1828
# Uploaded batch 1151/1828
# Uploaded batch 1152/1828
# Uploaded batch 1153/1828
# Uploaded batch 1154/1828
# Uploaded batch 1155/1828
# Uploaded batch 1156/1828
# Uploaded batch 1157/1828
# Uploaded batch 1158/1828
# Uploaded batch 1159/1828
# Uploaded batch 1160/1828
# Uploaded batch 1161/1828
# Uploaded batch 1162/1828
# Uploaded batch 1163/1828
# Uploaded batch 1164/1828
# Uploaded batch 1165/1828
# Uploaded batch 1166/1828
# Uploaded batch 1167/1828
# Uploaded batch 1168/1828
# Uploaded batch 1169/1828
# Uploaded batch 1170/1828
# Uploaded batch 1171/1828
# Uploaded batch 1172/1828
# Uploaded batch 1173/1828
# Uploaded batch 1174/1828
# Uploaded batch 1175/1828
# Uploaded batch 1176/1828
# Uploaded batch 1177/1828
# Uploaded batch 1178/1828
# Uploaded batch 1179/1828
# Uploaded batch 1180/1828
# Uploaded batch 1181/1828
# Uploaded batch 1182/1828
# Uploaded batch 1183/1828
# Uploaded batch 1184/1828
# Uploaded batch 1185/1828
# Uploaded batch 1186/1828
# Uploaded batch 1187/1828
# Uploaded batch 1188/1828
# Uploaded batch 1189/1828
# Uploaded batch 1190/1828
# Uploaded batch 1191/1828
# Uploaded batch 1192/1828
# Uploaded batch 1193/1828
# Uploaded batch 1194/1828
# Uploaded batch 1195/1828
# Uploaded batch 1196/1828
# Uploaded batch 1197/1828
# Uploaded batch 1198/1828
# Uploaded batch 1199/1828
# Uploaded batch 1200/1828
# Uploaded batch 1201/1828
# Uploaded batch 1202/1828
# Uploaded batch 1203/1828
# Uploaded batch 1204/1828
# Uploaded batch 1205/1828
# Uploaded batch 1206/1828
# Uploaded batch 1207/1828
# Uploaded batch 1208/1828
# Uploaded batch 1209/1828
# Uploaded batch 1210/1828
# Uploaded batch 1211/1828
# Uploaded batch 1212/1828
# Uploaded batch 1213/1828
# Uploaded batch 1214/1828
# Uploaded batch 1215/1828
# Uploaded batch 1216/1828
# Uploaded batch 1217/1828
# Uploaded batch 1218/1828
# Uploaded batch 1219/1828
# Uploaded batch 1220/1828
# Uploaded batch 1221/1828
# Uploaded batch 1222/1828
# Uploaded batch 1223/1828
# Uploaded batch 1224/1828
# Uploaded batch 1225/1828
# Uploaded batch 1226/1828
# Uploaded batch 1227/1828
# Uploaded batch 1228/1828
# Uploaded batch 1229/1828
# Uploaded batch 1230/1828
# Uploaded batch 1231/1828
# Uploaded batch 1232/1828
# Uploaded batch 1233/1828
# Uploaded batch 1234/1828
# Uploaded batch 1235/1828
# Uploaded batch 1236/1828
# Uploaded batch 1237/1828
# Uploaded batch 1238/1828
# Uploaded batch 1239/1828
# Uploaded batch 1240/1828
# Uploaded batch 1241/1828
# Uploaded batch 1242/1828
# Uploaded batch 1243/1828
# Uploaded batch 1244/1828
# Uploaded batch 1245/1828
# Uploaded batch 1246/1828
# Uploaded batch 1247/1828
# Uploaded batch 1248/1828
# Uploaded batch 1249/1828
# Uploaded batch 1250/1828
# Uploaded batch 1251/1828
# Uploaded batch 1252/1828
# Uploaded batch 1253/1828
# Uploaded batch 1254/1828
# Uploaded batch 1255/1828
# Uploaded batch 1256/1828
# Uploaded batch 1257/1828
# Uploaded batch 1258/1828
# Uploaded batch 1259/1828
# Uploaded batch 1260/1828
# Uploaded batch 1261/1828
# Uploaded batch 1262/1828
# Uploaded batch 1263/1828
# Uploaded batch 1264/1828
# Uploaded batch 1265/1828
# Uploaded batch 1266/1828
# Uploaded batch 1267/1828
# Uploaded batch 1268/1828
# Uploaded batch 1269/1828
# Uploaded batch 1270/1828
# Uploaded batch 1271/1828
# Uploaded batch 1272/1828
# Uploaded batch 1273/1828
# Uploaded batch 1274/1828
# Uploaded batch 1275/1828
# Uploaded batch 1276/1828
# Uploaded batch 1277/1828
# Uploaded batch 1278/1828
# Uploaded batch 1279/1828
# Uploaded batch 1280/1828
# Uploaded batch 1281/1828
# Uploaded batch 1282/1828
# Uploaded batch 1283/1828
# Uploaded batch 1284/1828
# Uploaded batch 1285/1828
# Uploaded batch 1286/1828
# Uploaded batch 1287/1828
# Uploaded batch 1288/1828
# Uploaded batch 1289/1828
# Uploaded batch 1290/1828
# Uploaded batch 1291/1828
# Uploaded batch 1292/1828
# Uploaded batch 1293/1828
# Uploaded batch 1294/1828
# Uploaded batch 1295/1828
# Uploaded batch 1296/1828
# Uploaded batch 1297/1828
# Uploaded batch 1298/1828
# Uploaded batch 1299/1828
# Uploaded batch 1300/1828
# Uploaded batch 1301/1828
# Uploaded batch 1302/1828
# Uploaded batch 1303/1828
# Uploaded batch 1304/1828
# Uploaded batch 1305/1828
# Uploaded batch 1306/1828
# Uploaded batch 1307/1828
# Uploaded batch 1308/1828
# Uploaded batch 1309/1828
# Uploaded batch 1310/1828
# Uploaded batch 1311/1828
# Uploaded batch 1312/1828
# Uploaded batch 1313/1828
# Uploaded batch 1314/1828
# Uploaded batch 1315/1828
# Uploaded batch 1316/1828
# Uploaded batch 1317/1828
# Uploaded batch 1318/1828
# Uploaded batch 1319/1828
# Uploaded batch 1320/1828
# Uploaded batch 1321/1828
# Uploaded batch 1322/1828
# Uploaded batch 1323/1828
# Uploaded batch 1324/1828
# Uploaded batch 1325/1828
# Uploaded batch 1326/1828
# Uploaded batch 1327/1828
# Uploaded batch 1328/1828
# Uploaded batch 1329/1828
# Uploaded batch 1330/1828
# Uploaded batch 1331/1828
# Uploaded batch 1332/1828
# Uploaded batch 1333/1828
# Uploaded batch 1334/1828
# Uploaded batch 1335/1828
# Uploaded batch 1336/1828
# Uploaded batch 1337/1828
# Uploaded batch 1338/1828
# Uploaded batch 1339/1828
# Uploaded batch 1340/1828
# Uploaded batch 1341/1828
# Uploaded batch 1342/1828
# Uploaded batch 1343/1828
# Uploaded batch 1344/1828
# Uploaded batch 1345/1828
# Uploaded batch 1346/1828
# Uploaded batch 1347/1828
# Uploaded batch 1348/1828
# Uploaded batch 1349/1828
# Uploaded batch 1350/1828
# Uploaded batch 1351/1828
# Uploaded batch 1352/1828
# Uploaded batch 1353/1828
# Uploaded batch 1354/1828
# Uploaded batch 1355/1828
# Uploaded batch 1356/1828
# Uploaded batch 1357/1828
# Uploaded batch 1358/1828
# Uploaded batch 1359/1828
# Uploaded batch 1360/1828
# Uploaded batch 1361/1828
# Uploaded batch 1362/1828
# Uploaded batch 1363/1828
# Uploaded batch 1364/1828
# Uploaded batch 1365/1828
# Uploaded batch 1366/1828
# Uploaded batch 1367/1828
# Uploaded batch 1368/1828
# Uploaded batch 1369/1828
# Uploaded batch 1370/1828
# Uploaded batch 1371/1828
# Uploaded batch 1372/1828
# Uploaded batch 1373/1828
# Uploaded batch 1374/1828
# Uploaded batch 1375/1828
# Uploaded batch 1376/1828
# Uploaded batch 1377/1828
# Uploaded batch 1378/1828
# Uploaded batch 1379/1828
# Uploaded batch 1380/1828
# Uploaded batch 1381/1828
# Uploaded batch 1382/1828
# Uploaded batch 1383/1828
# Uploaded batch 1384/1828
# Uploaded batch 1385/1828
# Uploaded batch 1386/1828
# Uploaded batch 1387/1828
# Uploaded batch 1388/1828
# Uploaded batch 1389/1828
# Uploaded batch 1390/1828
# Uploaded batch 1391/1828
# Uploaded batch 1392/1828
# Uploaded batch 1393/1828
# Uploaded batch 1394/1828
# Uploaded batch 1395/1828
# Uploaded batch 1396/1828
# Uploaded batch 1397/1828
# Uploaded batch 1398/1828
# Uploaded batch 1399/1828
# Uploaded batch 1400/1828
# Uploaded batch 1401/1828
# Uploaded batch 1402/1828
# Uploaded batch 1403/1828
# Uploaded batch 1404/1828
# Uploaded batch 1405/1828
# Uploaded batch 1406/1828
# Uploaded batch 1407/1828
# Uploaded batch 1408/1828
# Uploaded batch 1409/1828
# Uploaded batch 1410/1828
# Uploaded batch 1411/1828
# Uploaded batch 1412/1828
# Uploaded batch 1413/1828
# Uploaded batch 1414/1828
# Uploaded batch 1415/1828
# Uploaded batch 1416/1828
# Uploaded batch 1417/1828
# Uploaded batch 1418/1828
# Uploaded batch 1419/1828
# Uploaded batch 1420/1828
# Uploaded batch 1421/1828
# Uploaded batch 1422/1828
# Uploaded batch 1423/1828
# Uploaded batch 1424/1828
# Uploaded batch 1425/1828
# Uploaded batch 1426/1828
# Uploaded batch 1427/1828
# Uploaded batch 1428/1828
# Uploaded batch 1429/1828
# Uploaded batch 1430/1828
# Uploaded batch 1431/1828
# Uploaded batch 1432/1828
# Uploaded batch 1433/1828
# Uploaded batch 1434/1828
# Uploaded batch 1435/1828
# Uploaded batch 1436/1828
# Uploaded batch 1437/1828
# Uploaded batch 1438/1828
# Uploaded batch 1439/1828
# Uploaded batch 1440/1828
# Uploaded batch 1441/1828
# Uploaded batch 1442/1828
# Uploaded batch 1443/1828
# Uploaded batch 1444/1828
# Uploaded batch 1445/1828
# Uploaded batch 1446/1828
# Uploaded batch 1447/1828
# Uploaded batch 1448/1828
# Uploaded batch 1449/1828
# Uploaded batch 1450/1828
# Uploaded batch 1451/1828
# Uploaded batch 1452/1828
# Uploaded batch 1453/1828
# Uploaded batch 1454/1828
# Uploaded batch 1455/1828
# Uploaded batch 1456/1828
# Uploaded batch 1457/1828
# Uploaded batch 1458/1828
# Uploaded batch 1459/1828
# Uploaded batch 1460/1828
# Uploaded batch 1461/1828
# Uploaded batch 1462/1828
# Uploaded batch 1463/1828
# Uploaded batch 1464/1828
# Uploaded batch 1465/1828
# Uploaded batch 1466/1828
# Uploaded batch 1467/1828
# Uploaded batch 1468/1828
# Uploaded batch 1469/1828
# Uploaded batch 1470/1828
# Uploaded batch 1471/1828
# Uploaded batch 1472/1828
# Uploaded batch 1473/1828
# Uploaded batch 1474/1828
# Uploaded batch 1475/1828
# Uploaded batch 1476/1828
# Uploaded batch 1477/1828
# Uploaded batch 1478/1828
# Uploaded batch 1479/1828
# Uploaded batch 1480/1828
# Uploaded batch 1481/1828
# Uploaded batch 1482/1828
# Uploaded batch 1483/1828
# Uploaded batch 1484/1828
# Uploaded batch 1485/1828
# Uploaded batch 1486/1828
# Uploaded batch 1487/1828
# Uploaded batch 1488/1828
# Uploaded batch 1489/1828
# Uploaded batch 1490/1828
# Uploaded batch 1491/1828
# Uploaded batch 1492/1828
# Uploaded batch 1493/1828
# Uploaded batch 1494/1828
# Uploaded batch 1495/1828
# Uploaded batch 1496/1828
# Uploaded batch 1497/1828
# Uploaded batch 1498/1828
# Uploaded batch 1499/1828
# Uploaded batch 1500/1828
# Uploaded batch 1501/1828
# Uploaded batch 1502/1828
# Uploaded batch 1503/1828
# Uploaded batch 1504/1828
# Uploaded batch 1505/1828
# Uploaded batch 1506/1828
# Uploaded batch 1507/1828
# Uploaded batch 1508/1828
# Uploaded batch 1509/1828
# Uploaded batch 1510/1828
# Uploaded batch 1511/1828
# Uploaded batch 1512/1828
# Uploaded batch 1513/1828
# Uploaded batch 1514/1828
# Uploaded batch 1515/1828
# Uploaded batch 1516/1828
# Uploaded batch 1517/1828
# Uploaded batch 1518/1828
# Uploaded batch 1519/1828
# Uploaded batch 1520/1828
# Uploaded batch 1521/1828
# Uploaded batch 1522/1828
# Uploaded batch 1523/1828
# Uploaded batch 1524/1828
# Uploaded batch 1525/1828
# Uploaded batch 1526/1828
# Uploaded batch 1527/1828
# Uploaded batch 1528/1828
# Uploaded batch 1529/1828
# Uploaded batch 1530/1828
# Uploaded batch 1531/1828
# Uploaded batch 1532/1828
# Uploaded batch 1533/1828
# Uploaded batch 1534/1828
# Uploaded batch 1535/1828
# Uploaded batch 1536/1828
# Uploaded batch 1537/1828
# Uploaded batch 1538/1828
# Uploaded batch 1539/1828
# Uploaded batch 1540/1828
# Uploaded batch 1541/1828
# Uploaded batch 1542/1828
# Uploaded batch 1543/1828
# Uploaded batch 1544/1828
# Uploaded batch 1545/1828
# Uploaded batch 1546/1828
# Uploaded batch 1547/1828
# Uploaded batch 1548/1828
# Uploaded batch 1549/1828
# Uploaded batch 1550/1828
# Uploaded batch 1551/1828
# Uploaded batch 1552/1828
# Uploaded batch 1553/1828
# Uploaded batch 1554/1828
# Uploaded batch 1555/1828
# Uploaded batch 1556/1828
# Uploaded batch 1557/1828
# Uploaded batch 1558/1828
# Uploaded batch 1559/1828
# Uploaded batch 1560/1828
# Uploaded batch 1561/1828
# Uploaded batch 1562/1828
# Uploaded batch 1563/1828
# Uploaded batch 1564/1828
# Uploaded batch 1565/1828
# Uploaded batch 1566/1828
# Uploaded batch 1567/1828
# Uploaded batch 1568/1828
# Uploaded batch 1569/1828
# Uploaded batch 1570/1828
# Uploaded batch 1571/1828
# Uploaded batch 1572/1828
# Uploaded batch 1573/1828
# Uploaded batch 1574/1828
# Uploaded batch 1575/1828
# Uploaded batch 1576/1828
# Uploaded batch 1577/1828
# Uploaded batch 1578/1828
# Uploaded batch 1579/1828
# Uploaded batch 1580/1828
# Uploaded batch 1581/1828
# Uploaded batch 1582/1828
# Uploaded batch 1583/1828
# Uploaded batch 1584/1828
# Uploaded batch 1585/1828
# Uploaded batch 1586/1828
# Uploaded batch 1587/1828
# Uploaded batch 1588/1828
# Uploaded batch 1589/1828
# Uploaded batch 1590/1828
# Uploaded batch 1591/1828
# Uploaded batch 1592/1828
# Uploaded batch 1593/1828
# Uploaded batch 1594/1828
# Uploaded batch 1595/1828
# Uploaded batch 1596/1828
# Uploaded batch 1597/1828
# Uploaded batch 1598/1828
# Uploaded batch 1599/1828
# Uploaded batch 1600/1828
# Uploaded batch 1601/1828
# Uploaded batch 1602/1828
# Uploaded batch 1603/1828
# Uploaded batch 1604/1828
# Uploaded batch 1605/1828
# Uploaded batch 1606/1828
# Uploaded batch 1607/1828
# Uploaded batch 1608/1828
# Uploaded batch 1609/1828
# Uploaded batch 1610/1828
# Uploaded batch 1611/1828
# Uploaded batch 1612/1828
# Uploaded batch 1613/1828
# Uploaded batch 1614/1828
# Uploaded batch 1615/1828
# Uploaded batch 1616/1828
# Uploaded batch 1617/1828
# Uploaded batch 1618/1828
# Uploaded batch 1619/1828
# Uploaded batch 1620/1828
# Uploaded batch 1621/1828
# Uploaded batch 1622/1828
# Uploaded batch 1623/1828
# Uploaded batch 1624/1828
# Uploaded batch 1625/1828
# Uploaded batch 1626/1828
# Uploaded batch 1627/1828
# Uploaded batch 1628/1828
# Uploaded batch 1629/1828
# Uploaded batch 1630/1828
# Uploaded batch 1631/1828
# Uploaded batch 1632/1828
# Uploaded batch 1633/1828
# Uploaded batch 1634/1828
# Uploaded batch 1635/1828
# Uploaded batch 1636/1828
# Uploaded batch 1637/1828
# Uploaded batch 1638/1828
# Uploaded batch 1639/1828
# Uploaded batch 1640/1828
# Uploaded batch 1641/1828
# Uploaded batch 1642/1828
# Uploaded batch 1643/1828
# Uploaded batch 1644/1828
# Uploaded batch 1645/1828
# Uploaded batch 1646/1828
# Uploaded batch 1647/1828
# Uploaded batch 1648/1828
# Uploaded batch 1649/1828
# Uploaded batch 1650/1828
# Uploaded batch 1651/1828
# Uploaded batch 1652/1828
# Uploaded batch 1653/1828
# Uploaded batch 1654/1828
# Uploaded batch 1655/1828
# Uploaded batch 1656/1828
# Uploaded batch 1657/1828
# Uploaded batch 1658/1828
# Uploaded batch 1659/1828
# Uploaded batch 1660/1828
# Uploaded batch 1661/1828
# Uploaded batch 1662/1828
# Uploaded batch 1663/1828
# Uploaded batch 1664/1828
# Uploaded batch 1665/1828
# Uploaded batch 1666/1828
# Uploaded batch 1667/1828
# Uploaded batch 1668/1828
# Uploaded batch 1669/1828
# Uploaded batch 1670/1828
# Uploaded batch 1671/1828
# Uploaded batch 1672/1828
# Uploaded batch 1673/1828
# Uploaded batch 1674/1828
# Uploaded batch 1675/1828
# Uploaded batch 1676/1828
# Uploaded batch 1677/1828
# Uploaded batch 1678/1828
# Uploaded batch 1679/1828
# Uploaded batch 1680/1828
# Uploaded batch 1681/1828
# Uploaded batch 1682/1828
# Uploaded batch 1683/1828
# Uploaded batch 1684/1828
# Uploaded batch 1685/1828
# Uploaded batch 1686/1828
# Uploaded batch 1687/1828
# Uploaded batch 1688/1828
# Uploaded batch 1689/1828
# Uploaded batch 1690/1828
# Uploaded batch 1691/1828
# Uploaded batch 1692/1828
# Uploaded batch 1693/1828
# Uploaded batch 1694/1828
# Uploaded batch 1695/1828
# Uploaded batch 1696/1828
# Uploaded batch 1697/1828
# Uploaded batch 1698/1828
# Uploaded batch 1699/1828
# Uploaded batch 1700/1828
# Uploaded batch 1701/1828
# Uploaded batch 1702/1828
# Uploaded batch 1703/1828
# Uploaded batch 1704/1828
# Uploaded batch 1705/1828
# Uploaded batch 1706/1828
# Uploaded batch 1707/1828
# Uploaded batch 1708/1828
# Uploaded batch 1709/1828
# Uploaded batch 1710/1828
# Uploaded batch 1711/1828
# Uploaded batch 1712/1828
# Uploaded batch 1713/1828
# Uploaded batch 1714/1828
# Uploaded batch 1715/1828
# Uploaded batch 1716/1828
# Uploaded batch 1717/1828
# Uploaded batch 1718/1828
# Uploaded batch 1719/1828
# Uploaded batch 1720/1828
# Uploaded batch 1721/1828
# Uploaded batch 1722/1828
# Uploaded batch 1723/1828
# Uploaded batch 1724/1828
# Uploaded batch 1725/1828
# Uploaded batch 1726/1828
# Uploaded batch 1727/1828
# Uploaded batch 1728/1828
# Uploaded batch 1729/1828
# Uploaded batch 1730/1828
# Uploaded batch 1731/1828
# Uploaded batch 1732/1828
# Uploaded batch 1733/1828
# Uploaded batch 1734/1828
# Uploaded batch 1735/1828
# Uploaded batch 1736/1828
# Uploaded batch 1737/1828
# Uploaded batch 1738/1828
# Uploaded batch 1739/1828
# Uploaded batch 1740/1828
# Uploaded batch 1741/1828
# Uploaded batch 1742/1828
# Uploaded batch 1743/1828
# Uploaded batch 1744/1828
# Uploaded batch 1745/1828
# Uploaded batch 1746/1828
# Uploaded batch 1747/1828
# Uploaded batch 1748/1828
# Uploaded batch 1749/1828
# Uploaded batch 1750/1828
# Uploaded batch 1751/1828
# Uploaded batch 1752/1828
# Uploaded batch 1753/1828
# Uploaded batch 1754/1828
# Uploaded batch 1755/1828
# Uploaded batch 1756/1828
# Uploaded batch 1757/1828
# Uploaded batch 1758/1828
# Uploaded batch 1759/1828
# Uploaded batch 1760/1828
# Uploaded batch 1761/1828
# Uploaded batch 1762/1828
# Uploaded batch 1763/1828
# Uploaded batch 1764/1828
# Uploaded batch 1765/1828
# Uploaded batch 1766/1828
# Uploaded batch 1767/1828
# Uploaded batch 1768/1828
# Uploaded batch 1769/1828
# Uploaded batch 1770/1828
# Uploaded batch 1771/1828
# Uploaded batch 1772/1828
# Uploaded batch 1773/1828
# Uploaded batch 1774/1828
# Uploaded batch 1775/1828
# Uploaded batch 1776/1828
# Uploaded batch 1777/1828
# Uploaded batch 1778/1828
# Uploaded batch 1779/1828
# Uploaded batch 1780/1828
# Uploaded batch 1781/1828
# Uploaded batch 1782/1828
# Uploaded batch 1783/1828
# Uploaded batch 1784/1828
# Uploaded batch 1785/1828
# Uploaded batch 1786/1828
# Uploaded batch 1787/1828
# Uploaded batch 1788/1828
# Uploaded batch 1789/1828
# Uploaded batch 1790/1828
# Uploaded batch 1791/1828
# Uploaded batch 1792/1828
# Uploaded batch 1793/1828
# Uploaded batch 1794/1828
# Uploaded batch 1795/1828
# Uploaded batch 1796/1828
# Uploaded batch 1797/1828
# Uploaded batch 1798/1828
# Uploaded batch 1799/1828
# Uploaded batch 1800/1828
# Uploaded batch 1801/1828
# Uploaded batch 1802/1828
# Uploaded batch 1803/1828
# Uploaded batch 1804/1828
# Uploaded batch 1805/1828
# Uploaded batch 1806/1828
# Uploaded batch 1807/1828
# Uploaded batch 1808/1828
# Uploaded batch 1809/1828
# Uploaded batch 1810/1828
# Uploaded batch 1811/1828
# Uploaded batch 1812/1828
# Uploaded batch 1813/1828
# Uploaded batch 1814/1828
# Uploaded batch 1815/1828
# Uploaded batch 1816/1828
# Uploaded batch 1817/1828
# Uploaded batch 1818/1828
# Uploaded batch 1819/1828
# Uploaded batch 1820/1828
# Uploaded batch 1821/1828
# Uploaded batch 1822/1828
# Uploaded batch 1823/1828
# Uploaded batch 1824/1828
# Uploaded batch 1825/1828
# Uploaded batch 1826/1828
# Uploaded batch 1827/1828
# Uploaded batch 1828/1828
# Uploaded batch 1829/1828
# Upload to Pinecone complete.

# %% [markdown]
# ## Finish task
#
# ### Subtask:
# Summarize the process and confirm that the embeddings have been successfully uploaded to Pinecone.

# %% [markdown]
# **Reasoning**:
# Provide a summary of the steps taken and confirm the successful upload of embeddings to the Pinecone index.
